# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df2 = pd.read_csv("avocado.csv", usecols=["AveragePrice","Total Volume"])

# %%
df = df2.head(50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  50 non-null     float64
#  1   Total Volume  50 non-null     float64
# dtypes: float64(2)
# memory usage: 928.0 bytes

# %%
x = df["AveragePrice"].values.reshape(-1,1)
y = df["Total Volume"].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1)

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(linear_model.coef_)
print(linear_model.intercept_)
a = linear_model.coef_
b = linear_model.intercept_
print("Persamaan linearnya adalah")
print("Y = "+str(a)+" + "+ str(b)+"X")
# Out:
# [[-17454.15964847]]
# [96503.62867292]
# Persamaan linearnya adalah
# Y = [[-17454.15964847]] + [96503.62867292]X

# %%
linear_model.score(x_test,y_test)
# Out:
# -0.6590779481525375

# %%
price_predict = linear_model.predict(x_test)
plt.scatter(x_test, y_test)
plt.plot(x_test, price_predict, c='r')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.title('Plot horsepower vs price')
# Out:
# Text(0.5, 1.0, 'Plot horsepower vs price')
