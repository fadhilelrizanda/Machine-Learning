# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("cricket.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   chirps/sec-  15 non-null     float64
#  1   Fahrenheit   15 non-null     float64
# dtypes: float64(2)
# memory usage: 368.0 bytes

# %%
x = df["Fahrenheit"].values.reshape(-1,1)
y = df["chirps/sec-"].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.4)

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(linear_model.coef_)
print(linear_model.intercept_)
a = linear_model.coef_
b = linear_model.intercept_
print("Persamaan linearnya adalah")
print("Y = "+str(a)+" + "+ str(b)+"X")
# Out:
# [[0.22980666]]
# [-1.75265278]
# Persamaan linearnya adalah
# Y = [[0.22980666]] + [-1.75265278]X

# %%
linear_model.score(x_test,y_test)
# Out:
# 0.7938305812586655

# %%
price_predict = linear_model.predict(x_test)
plt.scatter(x_test, y_test)
plt.plot(x_test, price_predict, c='r')
plt.xlabel('Fahrenheit')
plt.ylabel('chirps/sec-')
plt.title('Plot Fahrenheit vs chirps/sec-')
# Out:
# Text(0.5, 1.0, 'Plot Fahrenheit vs chirps/sec-')

# %%
# menambahkan regulasi
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=0.5, normalize=True)
ridge.fit(x_train,y_train)
ridge_predict = ridge.predict(x_test)
ridge.score(x_test,y_test)
# Out:
# 0.7907765586045181

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, ridge_predict, c='y')
plt.xlabel('Fahrenheit')
plt.ylabel('chirps/sec-')
plt.title('Plot Fahrenheit vs chirps/sec-')
# Out:
# Text(0.5, 1.0, 'Plot Fahrenheit vs chirps/sec-')

# %%
#menambah regulasi
from sklearn.linear_model import Lasso
# define model
model = Lasso(alpha=1.0)
model.fit(x_train,y_train)
model.predict(x_test)
model.score(x_test,y_test)

# %%
l_predict = model.predict(x_test)
plt.scatter(x_test, y_test)
plt.plot(x_test, l_predict, c='k')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.title('Plot horsepower vs price')
